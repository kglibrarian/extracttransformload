# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "./data/TRI_Facility_Info_Chicago.csv"
facility_data_df = pd.read_csv(csv_file)
facility_data_df.head()
# Out:
#   _TRI_FACILITY_EZ.TRI_FACILITY_ID         V_TRI_FACILITY_EZ.FACILITY_NAME  \
# 0                  60632CPTLM3801W  CAPITOL MANUFACTURING CHICAGO FACILITY
# 1                  60622MTRLS900NP           MATERIAL SERVICE CORP  YARD 1
# 2                  60632BRKSH4950S                 BERKSHIRE FURNITURE INC
# 3                  6063WNDPND6226W                     INDEPENDENCE TUBE C
# 4                  60608MDWST1414S                MIDWEST FOLDING PRODUCTS
#
#   V_TRI_FACILITY_EZ.STREET_ADDRESS V_TRI_FACILITY_EZ.CITY_NAME  \
# 0                   3801 W 44TH ST                     CHICAGO
# 1                901 N SANGAMON ST                     CHICAGO
# 2              4950 S KILBOURN AVE                     CHICAGO
# 3                   6226 W 74TH ST                     CHICAGO
# 4               1414 S WESTERN AVE                     CHICAGO
#
#   V_TRI_FACILITY_EZ.COUNTY_NAME  V_TRI_FACILITY_EZ.STATE_COUNTY_FIPS_CODE  \
# ...

# %%
renamed_facility_df = facility_data_df.rename(columns={"_TRI_FACILITY_EZ.TRI_FACILITY_ID":"Facility_ID", 
                                                       "V_TRI_FACILITY_EZ.FACILITY_NAME":"Facility_Name", 
                                                       "V_TRI_FACILITY_EZ.STREET_ADDRESS": "Address", 
                                                       "V_TRI_FACILITY_EZ.CITY_NAME": "City", 
                                                       "V_TRI_FACILITY_EZ.COUNTY_NAME": "County", 
                                                       "V_TRI_FACILITY_EZ.STATE_ABBR": "State", 
                                                       "V_TRI_FACILITY_EZ.ZIP_CODE" : "Zipcode", 
                                                       "V_TRI_FACILITY_EZ.REGION": "Region", 
                                                       "V_TRI_FACILITY_EZ.FAC_CLOSED_IND": "Closed?", 
                                                       "V_TRI_FACILITY_EZ.PARENT_CO_DB_NUM" : "Parent_Company_ID", 
                                                       "V_TRI_FACILITY_EZ.PARENT_CO_NAME": "Parent_Company_Name", 
                                                       "V_TRI_FACILITY_EZ.LATITUDE": "Latitude", 
                                                       "V_TRI_FACILITY_EZ.LONGITUDE": "Longitude" })
renamed_facility_df.head()
# Out:
#        Facility_ID                           Facility_Name  \
# 0  60632CPTLM3801W  CAPITOL MANUFACTURING CHICAGO FACILITY
# 1  60622MTRLS900NP           MATERIAL SERVICE CORP  YARD 1
# 2  60632BRKSH4950S                 BERKSHIRE FURNITURE INC
# 3  6063WNDPND6226W                     INDEPENDENCE TUBE C
# 4  60608MDWST1414S                MIDWEST FOLDING PRODUCTS
#
#                Address     City County  \
# 0       3801 W 44TH ST  CHICAGO   COOK
# 1    901 N SANGAMON ST  CHICAGO   COOK
# 2  4950 S KILBOURN AVE  CHICAGO   COOK
# 3       6226 W 74TH ST  CHICAGO   COOK
# 4   1414 S WESTERN AVE  CHICAGO   COOK
#
#    V_TRI_FACILITY_EZ.STATE_COUNTY_FIPS_CODE State  Zipcode  Region  Closed?  \
# 0                                     17031    IL    60632       5        0
# 1                                     17031    IL    60622       5        1
# 2                                     17031    IL    60632       5        1
# ...

# %%
#final_facility_df = renamed_facility_df.drop(columns=['V_TRI_FACILITY_EZ.STATE_COUNTY_FIPS_CODE', 
                                        #"V_TRI_FACILITY_EZ.MAIL_NAME",
                                        #"V_TRI_FACILITY_EZ.MAIL_STREET_ADDRESS", 
                                        #"V_TRI_FACILITY_EZ.MAIL_CITY", 
                                        #"V_TRI_FACILITY_EZ.MAIL_STATE_ABBR",
                                        #"V_TRI_FACILITY_EZ.MAIL_COUNTRY", 
                                        #"V_TRI_FACILITY_EZ.MAIL_ZIP_CODE",
                                        #"V_TRI_FACILITY_EZ.ASGN_AGENCY",
                                        #"V_TRI_FACILITY_EZ.ASGN_FEDERAL_IND",
                                        #"V_TRI_FACILITY_EZ.STANDARDIZED_PARENT_COMPANY",
                                        #"V_TRI_FACILITY_EZ.ASGN_PARTIAL_IND",
                                        #"V_TRI_FACILITY_EZ.ASGN_PUBLIC_CONTACT",
                                        #"V_TRI_FACILITY_EZ.ASGN_PUBLIC_PHONE",
                                        #"V_TRI_FACILITY_EZ.ASGN_PUBLIC_CONTACT_EMAIL",
                                        #"V_TRI_FACILITY_EZ.REGISTRY_ID",
                                        #"V_TRI_FACILITY_EZ.ASGN_PUBLIC_PHONE_EXT",
                                        #"V_TRI_FACILITY_EZ.REF_POINT_DESC",
                                        #"V_TRI_FACILITY_EZ.REF_POINT_CODE",
                                        #"V_TRI_FACILITY_EZ.COLLECT_DESC",
                                        #"V_TRI_FACILITY_EZ.COLLECT_MTH_CODE",
                                        #"V_TRI_FACILITY_EZ.ACCURACY_VALUE",
                                        #"V_TRI_FACILITY_EZ.ACCURACY_SCORE",
                                        #"V_TRI_FACILITY_EZ.HDATUM_DESC",
                                        #"V_TRI_FACILITY_EZ.SCALE",
                                        #"V_TRI_FACILITY_EZ.SOURCE_DESC",
                                        #"V_TRI_FACILITY_EZ.SOURCE_CODE",
                                        #"V_TRI_FACILITY_EZ.CONVEYOR",
                                        #"V_TRI_FACILITY_EZ.BIA_CODE",
                                        #"V_TRI_FACILITY_EZ.TRIBE"])

#final_facility_df.head()

# %%
final_facility_df = renamed_facility_df[["Facility_ID", 
                                           "Facility_Name", 
                                           "Address", 
                                           "City", 
                                           "County", 
                                           "State", 
                                           "Zipcode", 
                                           "Region", 
                                           "Closed?", 
                                           "Parent_Company_ID", 
                                           "Parent_Company_Name", 
                                           "Latitude", 
                                           "Longitude" ]].copy()
final_facility_df.head()
# Out:
#        Facility_ID                           Facility_Name  \
# 0  60632CPTLM3801W  CAPITOL MANUFACTURING CHICAGO FACILITY
# 1  60622MTRLS900NP           MATERIAL SERVICE CORP  YARD 1
# 2  60632BRKSH4950S                 BERKSHIRE FURNITURE INC
# 3  6063WNDPND6226W                     INDEPENDENCE TUBE C
# 4  60608MDWST1414S                MIDWEST FOLDING PRODUCTS
#
#                Address     City County State  Zipcode  Region  Closed?  \
# 0       3801 W 44TH ST  CHICAGO   COOK    IL    60632       5        0
# 1    901 N SANGAMON ST  CHICAGO   COOK    IL    60622       5        1
# 2  4950 S KILBOURN AVE  CHICAGO   COOK    IL    60632       5        1
# 3       6226 W 74TH ST  CHICAGO   COOK    IL    60638       5        0
# 4   1414 S WESTERN AVE  CHICAGO   COOK    IL    60608       5        0
#
#   Parent_Company_ID    Parent_Company_Name   Latitude  Longitude
# 0           3002268            HARSCO CORP  41.813410 -87.719570
# ...

# %%
csv_file = "./data/TRI_Submission_Chicago_CAS.csv"
submission_data_df = pd.read_csv(csv_file)
submission_data_df.head()
# Out:
#   _TRI_SUBMISSIONS_EZ.TRI_FACILITY_ID  \
# 0                     60623BLLCT2001S
# 1                     60623CNTRL3200S
# 2                     60622NZDRC1087N
# 3                     60609SFTYK1445W
# 4                     60638DBRTC4700S
#
#                 V_TRI_SUBMISSIONS_EZ.FACILITY_NAME  \
# 0                     ABLE ELECTROPOLISHING CO INC
# 1                                        BWAY CORP
# 2                                   NAZDAR CHICAGO
# 3  CLEAN HARBORS RECYCLING SERVICES OF CHICAGO LLC
# 4                              DAUBERT CHEMICAL CO
#
#    V_TRI_SUBMISSIONS_EZ.DOC_CTRL_NUM  V_TRI_SUBMISSIONS_EZ.REPORTING_YEAR  \
# 0                       1.302200e+12                                 2002
# 1                       1.311210e+12                                 2011
# 2                       1.307210e+12                                 2007
# 3                       1.315210e+12                                 2015
# ...

# %%
renamed_submission_df = submission_data_df.rename(columns={"_TRI_SUBMISSIONS_EZ.TRI_FACILITY_ID":"Facility_ID", 
                                                       "V_TRI_SUBMISSIONS_EZ.FACILITY_NAME":"Facility_Name", 
                                                       "V_TRI_SUBMISSIONS_EZ.REPORTING_YEAR": "Year", 
                                                       "V_TRI_SUBMISSIONS_EZ.CHEM_NAME": "Chem_Name", 
                                                       "V_TRI_SUBMISSIONS_EZ.CAS_NUM": "CAS_Num", 
                                                       "V_TRI_SUBMISSIONS_EZ.TRI_CHEM_ID": "Chem_ID", 
                                                       "V_TRI_SUBMISSIONS_EZ.ACTIVE_DATE" : "Active_Date", 
                                                       "V_TRI_SUBMISSIONS_EZ.INACTIVE_DATE": "Inactive_Date", 
                                                       "V_TRI_SUBMISSIONS_EZ.CARCINOGEN": "Carcinogen?", 
                                                       "V_TRI_SUBMISSIONS_EZ.CLEAN_AIR" : "Clean_Air_Act?", 
                                                       "V_TRI_SUBMISSIONS_EZ.LIST_3350": "3350_Chem_List", 
                                                       "V_TRI_SUBMISSIONS_EZ.MAX_AMOUNT_OF_CHEM": "Max_lbs_chem_year", 
                                                       "V_TRI_SUBMISSIONS_EZ.CAS_CHEM_NAME": "CAS_Chem_Name",
                                                       "V_TRI_SUBMISSIONS_EZ.PRIMARY_SIC_CODE": "Primary_SIC_Code",
                                                       "V_TRI_SUBMISSIONS_EZ.INDUSTRY_CODE": "Industry_Code", 
                                                       "V_TRI_SUBMISSIONS_EZ.PRIMARY_NAICS_CODE": "Primary_NAICS_Code"})
renamed_submission_df.head()
# Out:
#        Facility_ID                                    Facility_Name  \
# 0  60623BLLCT2001S                     ABLE ELECTROPOLISHING CO INC
# 1  60623CNTRL3200S                                        BWAY CORP
# 2  60622NZDRC1087N                                   NAZDAR CHICAGO
# 3  60609SFTYK1445W  CLEAN HARBORS RECYCLING SERVICES OF CHICAGO LLC
# 4  60638DBRTC4700S                              DAUBERT CHEMICAL CO
#
#    V_TRI_SUBMISSIONS_EZ.DOC_CTRL_NUM  Year               Chem_Name    CAS_Num  \
# 0                       1.302200e+12  2002                  NICKEL  7440-02-0
# 1                       1.311210e+12  2011            ETHYLBENZENE   100-41-4
# 2                       1.307210e+12  2007  1 2 4-TRIMETHYLBENZENE    95-63-6
# 3                       1.315210e+12  2015                 TOLUENE   108-88-3
# 4                       1.306200e+12  2006                METHANOL    67-56-1
#
#    Chem_ID  Active_Date  Inactive_Date Carcinogen?  ...  \
# ...

# %%
final_submission_df = renamed_submission_df[["Facility_ID", 
                                         "Facility_Name", 
                                         "Year", 
                                         "Chem_Name", 
                                         "CAS_Num", 
                                         "Chem_ID", 
                                         "Active_Date", 
                                         "Inactive_Date", 
                                         "Carcinogen?", 
                                         "Clean_Air_Act?", 
                                         "3350_Chem_List", 
                                         "Max_lbs_chem_year", 
                                         "CAS_Chem_Name",
                                         "Primary_SIC_Code",
                                         "Industry_Code", 
                                         "Primary_NAICS_Code"]].copy()
final_submission_df.head()
# Out:
#        Facility_ID                                    Facility_Name  Year  \
# 0  60623BLLCT2001S                     ABLE ELECTROPOLISHING CO INC  2002
# 1  60623CNTRL3200S                                        BWAY CORP  2011
# 2  60622NZDRC1087N                                   NAZDAR CHICAGO  2007
# 3  60609SFTYK1445W  CLEAN HARBORS RECYCLING SERVICES OF CHICAGO LLC  2015
# 4  60638DBRTC4700S                              DAUBERT CHEMICAL CO  2006
#
#                 Chem_Name    CAS_Num  Chem_ID  Active_Date  Inactive_Date  \
# 0                  NICKEL  7440-02-0  7440020         1987           9999
# 1            ETHYLBENZENE   100-41-4   100414         1987           9999
# 2  1 2 4-TRIMETHYLBENZENE    95-63-6    95636         1987           9999
# 3                 TOLUENE   108-88-3   108883         1987           9999
# 4                METHANOL    67-56-1    67561         1987           9999
#
#   Carcinogen? Clean_Air_Act? 3350_Chem_List Max_lbs_chem_year  \
# ...

# %%
rds_connection_string = "root:NLM71011@127.0.0.1/tri_chicago_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
final_facility_df.to_sql(name='facility', con=engine, if_exists='append', index=False)

# %%
final_submission_df.to_sql(name='submission', con=engine, if_exists='append', index=False)

# %%
# Read XML from file
# filepath = "./data/hsdb.xml.20190428"
filepath = os.path.join(".", "data", "hsdb.xml.20190428")
print(filepath)
with open(filepath) as file:
    xml = file.read()

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse(filepath)

# %%
root = tree.getroot()

# %%
root.tag

root.attrib

for child in root:
    print(child.tag, child.attrib)

root[0]

root[0][1]

for doc in root.findall("DOC"):
    #date = doc.find("date").text
    cas = doc.find("CASRegistryNumber").text
    print(cas)

print(cas)
